# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon.csv')
df = df.iloc[:, :24]
df = df.drop(columns=['german_name', 'japanese_name', 'type_number', 'type_2'])
df = df.rename(columns={'Unnamed: 0': 'csv_index'})
df = df.set_index('csv_index')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1045 entries, 0 to 1044
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pokedex_number    1045 non-null   int64
#  1   name              1045 non-null   object
#  2   generation        1045 non-null   int64
#  3   status            1045 non-null   object
#  4   species           1045 non-null   object
#  5   type_1            1045 non-null   object
#  6   height_m          1045 non-null   float64
#  7   weight_kg         1044 non-null   float64
#  8   abilities_number  1045 non-null   int64
#  9   ability_1         1042 non-null   object
#  10  ability_2         516 non-null    object
#  11  ability_hidden    813 non-null    object
#  12  total_points      1045 non-null   int64
#  13  hp                1045 non-null   int64
#  14  attack            1045 non-null   int64
#  15  defense           1045 non-null   int64
# ...

# %%
duplicates = df[df['pokedex_number'].duplicated(keep=False)]
duplicates
# Out:
#            pokedex_number                         name  generation  \
# csv_index
# 2                       3                     Venusaur           1
# 3                       3                Mega Venusaur           1
# 6                       6                    Charizard           1
# 7                       6             Mega Charizard X           1
# 8                       6             Mega Charizard Y           1
# ...                   ...                          ...         ...
# 1035                  892  Urshifu Single Strike Style           8
# 1036                  892   Urshifu Rapid Strike Style           8
# 1042                  898                      Calyrex           8
# 1043                  898            Calyrex Ice Rider           8
# 1044                  898         Calyrex Shadow Rider           8
#
#                   status            species    type_1  height_m  weight_kg  \
# csv_index
# ...

# %%
duplicates['dup_count'] = duplicates.groupby('pokedex_number').cumcount()
# Out:
# C:\Users\amege\AppData\Local\Temp\ipykernel_7976\2421047973.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates['dup_count'] = duplicates.groupby('pokedex_number').cumcount()

# %%
duplicates[['pokedex_number', 'name', 'dup_count']]
# Out:
#            pokedex_number                         name  dup_count
# csv_index
# 2                       3                     Venusaur          0
# 3                       3                Mega Venusaur          1
# 6                       6                    Charizard          0
# 7                       6             Mega Charizard X          1
# 8                       6             Mega Charizard Y          2
# ...                   ...                          ...        ...
# 1035                  892  Urshifu Single Strike Style          0
# 1036                  892   Urshifu Rapid Strike Style          1
# 1042                  898                      Calyrex          0
# 1043                  898            Calyrex Ice Rider          1
# 1044                  898         Calyrex Shadow Rider          2
#
# [267 rows x 3 columns]

# %%
duplicates['new_pokedex'] = duplicates.apply(
    lambda row: f"{str(row['pokedex_number']).zfill(3)}_f{row['dup_count']+1}" if row['dup_count'] > 0 else str(row['pokedex_number']).zfill(3),
    axis=1
)
duplicates[['pokedex_number', 'name', 'dup_count', 'new_pokedex']]
# Out:
# C:\Users\amege\AppData\Local\Temp\ipykernel_7976\3022470026.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates['new_pokedex'] = duplicates.apply(
#            pokedex_number                         name  dup_count new_pokedex
# csv_index
# 2                       3                     Venusaur          0         003
# 3                       3                Mega Venusaur          1      003_f2
# 6                       6                    Charizard          0         006
# 7                       6             Mega Charizard X          1      006_f2
# 8                       6             Mega Charizard Y          2      006_f3
# ...                   ...                          ...        ...         ...
# ...
